# %% [markdown]
# # COMPUTER VISION TOOLBOX
# ## MELDRICK FERDINAND REIMMER (MsCV 1)
# ### 01/03/2018

# %% [markdown]
# ### Importing the Libraries

# %%
from tkinter import *
import tkinter as tk
import tkinter.filedialog
from tkinter.filedialog import *
import cv2
import numpy as np
import glob
from PIL import Image, ImageTk
from tkinter import filedialog
from matplotlib import pyplot as plt

# %% [markdown]
# ### Definging the functions to use here

# %%
# Defining my functions here

#Getting Image to use
def LoadingImage():

        filename = filedialog.askopenfilename()
        img = cv2.imread(filename)
        #cv2.imwrite('picture.jpg', img)
        #i = Image.open('picture.jpg') 
        cv2.imshow('image',img)
        cv2.imwrite("Saved Photos/Image.jpg", img)
        global a
        a = img
        
        
#Region Of Interest
def RegionOFInterest():
    # Select ROI
    r = cv2.selectROI(a)
    # Crop image
    imCrop = a[int(r[1]):int(r[1]+r[3]), int(r[0]):int(r[0]+r[2])]
     # Display cropped image
    cv2.imshow("Image", imCrop)
    cv2.imwrite("ROI.jpg",imCrop)
    cv2.waitKey(0)
    
def HoughTransformCir ():
        
        img = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
        img = cv2.medianBlur(img,5)
        cimg = cv2.cvtColor(img,cv2.COLOR_GRAY2BGR)
     
        circles = cv2.HoughCircles(img,cv2.HOUGH_GRADIENT,1,20,
                                 param1=50,param2=30,minRadius=10,maxRadius=90)
    
        circles = np.uint16(np.around(circles))
        for i in circles[0,:]:
            # draw the outer circle
            cv2.circle(cimg,(i[0],i[1]),i[2],(0,255,0),2)
            # draw the center of the circle
            cv2.circle(cimg,(i[0],i[1]),2,(0,0,255),3)
            
        cv2.imshow('image', img)
        cv2.imshow('cimg', cimg)
        cv2.imwrite("Saved Photos/resulthoughCircle.jpg", cimg)
        
def HoughTransformLin ():
        gray = cv2.cvtColor(a,cv2.COLOR_BGR2GRAY)
        edges = cv2.Canny(gray,100,200,apertureSize = 3)
         #cv2.imshow('edges',edges)
        cv2.waitKey(0)

        minLineLength = 30
        maxLineGap = 10
        lines = cv2.HoughLinesP(edges,1,np.pi/180,15,minLineLength,maxLineGap)
        for x in range(0, len(lines)):
            for x1,y1,x2,y2 in lines[x]:
                cv2.line(a,(x1,y1),(x2,y2),(0,255,0),2)

        cv2.imshow('Lines Extracted',a)
        cv2.imwrite("Saved Photos/resulthoughLine.jpg", cimg)
        cv2.waitKey(0)

    
    
    #Shape DesCriptors
def BoundingBox ():
        img = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
        ret,thresh = cv2.threshold(img,127,255,0)
        contours = cv2.findContours(thresh, 1, 2)
    
        cnt = contours[0]
        x,y,w,h = cv2.boundingRect(cnt)
        rect = cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)
        
        cv2.imshow('rect', rect)
        cv2.imwrite("Saved Photos/result_bb.jpg", rect)
        
def Circle():
        img = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
        ret,thresh = cv2.threshold(img,127,255,0)
        contours = cv2.findContours(thresh, 1, 2)
    
        cnt = contours[0]
        (x,y),radius = cv2.minEnclosingCircle(cnt)
        center = (int(x),int(y))
        radius = int(radius)
        cv2.circle(img,center,radius,(0,255,0),2)
        cv2.imwrite("Saved Photos/result_CC.jpg", img)
       
    
#Converting to Colour space
def ColorSpaces():
        hsv = cv2.cvtColor(a, cv2.COLOR_BGR2HSV)
        lab = cv2.cvtColor(a, cv2.COLOR_BGR2LAB)
        YCr = cv2.cvtColor(a,cv2.COLOR_BGR2YCrCb)
        cv2.imshow('Image in HSV',hsv)
        cv2.imshow('Image in LAB',lab)
        cv2.imshow('Image in YCrCb',YCr)
        cv2.imwrite("Saved Photos/result_HSV.jpg", hsv)
        cv2.imwrite("Saved Photos/result_Lab.jpg", lab)
        cv2.imwrite("Saved Photos/result_YCRCB.jpg", YCr)
    
        
#Edge Detectors Operators
def Sobel():
        img = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
        sobel = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
        #cv2.imshow('image',img)
        cv2.imshow('Sobel',sobel)
        cv2.imwrite("Saved Photos/SobelResults.jpg", sobel)

        
def Laplacian():
        img = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
        laplacian = cv2.Laplacian(img,cv2.CV_64F)
        #cv2.imshow('image',img)
        cv2.imshow('Laplacian',laplacian)
        cv2.imwrite("Saved Photos/LaplacianResults.jpg", laplacian)
        
def Canny ():
        img = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
        
        canny = cv2.Canny(img,100,200)
        
        #cv2.imshow('image', img)
        cv2.imshow('canny', canny)
        cv2.imwrite("Saved Photos/CannyResults.png", Canny)
        
     

 #Morphological Operators
def Erosion():
        img = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
        kernel = np.ones((5,5),np.uint8)
        erosion = cv2.erode(img,kernel,iterations = 1)
        cv2.imshow('erosion', erosion)
        cv2.imwrite("Saved Photos/ErosionResults.jpg", erosion)
        
        
def Dilation():
        img = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
        kernel = np.ones((5,5),np.uint8)
        dilation = cv2.dilate(img,kernel,iterations = 1)
        cv2.imshow('dilation', dilation)
        cv2.imwrite("Saved Photos/DilationResults.jpg", dilation)
        
def Open():
        img = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
        kernel = np.ones((5,5),np.uint8)
        opening = cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)
        cv2.imshow('openingn', opening)
        cv2.imwrite("Saved Photos/OpenResults.jpg", opening)
        
def Close():
        img = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
        kernel = np.ones((5,5),np.uint8)
        closing = cv2.morphologyEx(img, cv2.MORPH_CLOSE, kernel)
        cv2.imshow('closing', closing)
        cv2.imwrite("Saved Photos/closeResults.jpg", closing)
        
        
# Noise Functions
def SaltPepper():
        row,col,ch = a.shape
        sNp = 0.9
        amount = 0.005
        out = np.copy(a)
        
        # Salt mode
        num_salt = np.ceil(amount * a.size * sNp)
        coords = [np.random.randint(0, i - 1, int(num_salt))
            for i in a.shape]
        out[coords] = 1
        
        # Pepper mode
        num_pepper = np.ceil(amount* a.size * (1. - sNp))
        coords = [np.random.randint(0, i - 1, int(num_pepper))
              for i in a.shape]
        out[coords] = 0
        
        cv2.imshow('Salt & Pepper',out)
        cv2.imwrite("Saved Photos/Salt&PepperResults.jpg", out)
        
def Gaussian():
        row,col,ch= a.shape
        mean = 0
        var = 0.1
        sigma = var**0.5
        gauss = np.random.normal(mean,sigma,(row,col,ch))
        gauss = gauss.reshape(row,col,ch)
        noisy = a + gauss
        cv2.imshow('Gaussian',noisy)
        cv2.imwrite("Saved Photos/GaussianResults.jpg", noisy)
        
def Poisson():
        vals = len(np.unique(a))
        vals = 2 ** np.ceil(np.log2(vals))
        poisson = np.random.poisson(a * vals) / float(vals)
        cv2.imshow('Poisson',poisson)
        cv2.imwrite("Saved Photos/PoissonResults.jpg", poisson)
        
def Speckle():
        row,col,ch = a.shape
        gauss = np.random.randn(row,col,ch)
        gauss = gauss.reshape(row,col,ch)        
        speck = a + a * gauss
        cv2.imshow('Speckle',speck)
        cv2.imwrite("Saved Photos/SpeckleResults.jpg", speck)
        
# Filtering
def GaussianBlur():
        blur = cv2.GaussianBlur(a,(5,5),0)
        cv2.imshow('GaussBlur',blur)
        cv2.imwrite("Saved Photos/GaussianblurResults.jpg", blur)
        
def Medianfilter():
    median = cv2.medianBlur(a,5)
    cv2.imshow('MedianBlur',median)
    cv2.imwrite("Saved Photos/MedianResults.jpg", median)
    
def Bilateralfilter():
    bilateral = cv2.bilateralFilter(a,9,75,75)
    cv2.imshow('BilateralBlur',bilateral)
    cv2.imwrite("Saved Photos/BilateralResults.jpg", bilateral)
    
def Averagingfilter():
    avg = cv2.blur(a,(5,5))
    cv2.imshow('Averageblur',avg)
    cv2.imwrite("Saved Photos/AverageResults.jpg", avg)
    
#Histogram
def Histogram():
        hist = cv2.calcHist([a],[0],None,[256],[0,256])
        
        #Found on https://docs.opencv.org/3.3.1/d1/db7/tutorial_py_histogram_begins.html
        color = ('b','g','r')
        for i,col in enumerate(color):
            histo = cv2.calcHist([a],[i],None,[256],[0,256])
        plt.plot(histo,color = col)
        plt.xlim([0,256])
        cv2.imwrite("histogram.jpg",histo)
        plt.show()
        
def Equalization():
        hist = cv2.calcHist([a],[0],None,[256],[0,256])
        
        color = ('b','g','r')
        for i,col in enumerate(color):
            hist = cv2.calcHist([a],[i],None,[256],[0,256])
            
        cdf = hist.cumsum()
        cdf_normalized = cdf * hist.max()/ cdf.max()
        
        plt.plot(hist,color = col)
        plt.xlim([0,256])
    
        plt.plot(cdf_normalized, color = 'b')
        plt.legend(('cdf','histogram'), loc = 'upper left')
        plt.show()
    
    
    
    
#Corner Detecttion
def Harris():
        img = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
        gray = np.float32(img)
        dst = cv2.cornerHarris(gray,2,3,0.04)

        #result is dilated for marking the corners, not important
        dst = cv2.dilate(dst,None)

        # Threshold for an optimal value, it may vary depending on the image.
        img[dst>0.01*dst.max()]=[255]

        cv2.imshow('Corners',img)
        cv2.imwrite("Saved Photos/HarrisResults.jpg", img)
        
#Feature Detection
def SIFT():
        img1 = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
        filename2 = filedialog.askopenfilename()
        img2 = cv2.imread(filename2)
        img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
        
        sift=cv2.SIFT()

        # find the keypoints and descriptors with SIFT
        kp1, des1 = sift.detectAndCompute(img1,None)
        kp2, des2 = sift.detectAndCompute(img2,None)

        # BFMatcher with default params
        bf = cv2.BFMatcher()
        matches = bf.knnMatch(des1,des2, k=2)

        # Apply ratio test
        good = []
        for m,n in matches:
            if m.distance < 0.75*n.distance:
                good.append([m])

        # cv2.drawMatchesKnn expects list of lists as matches.
        img3 = cv2.drawMatchesKnn(img1,kp1,img2,kp2,good,None,flags=2)

        cv2.imshow('image3',img3)
        cv2.imwrite("result_sift.jpg",img3)

def FAST():

     # Initiate FAST object with default values
    fast = cv2.FastFeatureDetector_create()

    # find and draw the keypoints
    kp = fast.detect(a,None)
    img2 = cv2.drawKeypoints(a, kp, color=(255,0,0))

    cv2.imwrite('fast_true.png',img2)

    # Disable nonmaxSuppression
    fast.setBool('nonmaxSuppression',0)
    kp = fast.detect(img,None)
    img3 = cv2.drawKeypoints(img, kp, color=(255,0,0))

    cv2.imwrite('fast_false.png',img3)
    
    
def SIFT2():
    gray= cv2.cvtColor(a,cv2.COLOR_BGR2GRAY)

    sift = cv2.SIFT()
    kp = sift.detect(gray,None)

    a=cv2.drawKeypoints(gray,kp)

    cv2.imshow('sift_keypoints.jpg',a)
    a=cv2.drawKeypoints(gray,kp,flags=cv2.DRAW_MATCHES_FLAGS_DRAW_RICH_KEYPOINTS)
    cv2.imwshow('sift_keypoints.jpg',a)
    
def Epipolar():
        filename = filedialog.askopenfilename()
        img = cv2.imread(filename)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        filename2 = filedialog.askopenfilename()
        img2 = cv2.imread(filename2)
        img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
        
        img1 = cv2.resize(img, (0,0), fx=0.2, fy=0.2)
        img2 = cv2.resize(img2, (0,0), fx=0.2, fy=0.2)

        sift = cv2.xfeatures2d.SIFT_create()

        # find the keypoints and descriptors with SIFT
        kp1, des1 = sift.detectAndCompute(img1,None)
        kp2, des2 = sift.detectAndCompute(img2,None)

        # FLANN parameters
        FLANN_INDEX_KDTREE = 0
        index_params = dict(algorithm = FLANN_INDEX_KDTREE, trees = 5)
        search_params = dict(checks=50)

        flann = cv2.FlannBasedMatcher(index_params,search_params)
        matches = flann.knnMatch(des1,des2,k=2)

        good = []
        pts1 = []
        pts2 = []

        # ratio test as per Lowe's paper
        for i,(m,n) in enumerate(matches):
            if m.distance < 0.8*n.distance:
                good.append(m)
                pts2.append(kp2[m.trainIdx].pt)
                pts1.append(kp1[m.queryIdx].pt)
                
        pts1 = np.int32(pts1)
        pts2 = np.int32(pts2)
        F, mask = cv2.findFundamentalMat(pts1,pts2,cv2.FM_LMEDS)

        # We select only inlier points
        pts1 = pts1[mask.ravel()==1]
        pts2 = pts2[mask.ravel()==1]
        
        
        def drawlines(img1,img2,lines,pts1,pts2):
            ''' img1 - image on which we draw the epilines for the points in img2
        lines - corresponding epilines '''
            r,c = img1.shape
            img1 = cv2.cvtColor(img1,cv2.COLOR_GRAY2BGR)
            img2 = cv2.cvtColor(img2,cv2.COLOR_GRAY2BGR)
            for r,pt1,pt2 in zip(lines,pts1,pts2):
                color = tuple(np.random.randint(0,255,3).tolist())
                x0,y0 = map(int, [0, -r[2]/r[1] ])
                x1,y1 = map(int, [c, -(r[2]+r[0]*c)/r[1] ])
                img1 = cv2.line(img1, (x0,y0), (x1,y1), color,1)
                img1 = cv2.circle(img1,tuple(pt1),5,color,-1)
                img2 = cv2.circle(img2,tuple(pt2),5,color,-1)
            return img1,img2
        
        # Find epilines corresponding to points in right image (second image) and
        # drawing its lines on left image
        lines1 = cv2.computeCorrespondEpilines(pts2.reshape(-1,1,2), 2,F)
        lines1 = lines1.reshape(-1,3)
        img5,img6 = drawlines(img1,img2,lines1,pts1,pts2)

        # Find epilines corresponding to points in left image (first image) and
        # drawing its lines on right image
        lines2 = cv2.computeCorrespondEpilines(pts1.reshape(-1,1,2), 1,F)
        lines2 = lines2.reshape(-1,3)
        img3,img4 = drawlines(img2,img1,lines2,pts2,pts1)

        cv2.imshow('img5', img5)
        cv2.imshow('img3', img3)
        cv2.imwrite("result_epipolar.jpg", img3)

def Calibration():
        criteria = (cv2.TERM_CRITERIA_EPS + cv2.TERM_CRITERIA_MAX_ITER, 30, 0.001)

        # prepare object points, like (0,0,0), (1,0,0), (2,0,0) ....,(6,5,0)
        objp = np.zeros((6*7,3), np.float32)
        objp[:,:2] = np.mgrid[0:7,0:6].T.reshape(-1,2)

        # Arrays to store object points and image points from all the images.
        objpoints = [] # 3d point in real world space
        imgpoints = [] # 2d points in image plane.

        images = glob.glob('calib_radial.jpg')

        for fname in images:
            img = cv2.imread(fname)
            gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

            # Find the chess board corners
            ret, corners = cv2.findChessboardCorners(gray, (7,6),None)

            # If found, add object points, image points (after refining them)
            if ret == True:
                objpoints.append(objp)

                corners2 = cv2.cornerSubPix(gray,corners,(11,11),(-1,-1),criteria)
                imgpoints.append(corners2)

                # Draw and display the corners
                img = cv2.drawChessboardCorners(img, (7,6), corners2,ret)
                cv2.imshow('img',img)
                
        ret, mtx, dist, rvecs, tvecs = cv2.calibrateCamera(objpoints, imgpoints, gray.shape[::-1],None,None)###HERE Problem
        
        #http://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_calib3d/py_calibration/py_calibration.html#calibration
        filename = filedialog.askopenfilename()
        img = cv2.imread(filename)
        img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
      
        h,  w = img.shape[:2]
        newcameramtx, roi=cv2.getOptimalNewCameraMatrix(mtx,dist,(w,h),1,(w,h))
        
        # undistort
        dst = cv2.undistort(img, mtx, dist, None, newcameramtx)

        # crop the image
        x,y,w,h = roi
        dst = dst[y:y+h, x:x+w]
        cv2.imshow('img',img)
        cv2.imshow('results',dst)
        cv2.imwrite("result_calibration.jpg", dst)
        
def Homography():
        MIN_MATCH_COUNT = 5

        
        img1 = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
        filename2 = filedialog.askopenfilename()
        img2 = cv2.imread(filename2)
        img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)

        # Initiate SIFT detector
        sift = cv2.xfeatures2d.SIFT_create()

        # find the keypoints and descriptors with SIFT
        kp1, des1 = sift.detectAndCompute(img1,None)
        kp2, des2 = sift.detectAndCompute(img2,None)

        FLANN_INDEX_KDTREE = 0
        index_params = dict(algorithm = FLANN_INDEX_KDTREE, trees = 5)
        search_params = dict(checks = 50)

        flann = cv2.FlannBasedMatcher(index_params, search_params)

        matches = flann.knnMatch(des1,des2,k=2)

        # store all the good matches as per Lowe's ratio test.
        good = []
        for m,n in matches:
            if m.distance < 0.7*n.distance:
                good.append(m)
         
        
        if len(good)>MIN_MATCH_COUNT:
            src_pts = np.float32([ kp1[m.queryIdx].pt for m in good ]).reshape(-1,1,2)
            dst_pts = np.float32([ kp2[m.trainIdx].pt for m in good ]).reshape(-1,1,2)

            M, mask = cv2.findHomography(src_pts, dst_pts, cv2.RANSAC,5.0)
            matchesMask = mask.ravel().tolist()

            h,w = img1.shape
            pts = np.float32([ [0,0],[0,h-1],[w-1,h-1],[w-1,0] ]).reshape(-1,1,2)
            dst = cv2.perspectiveTransform(pts,M)

            img2 = cv2.polylines(img2,[np.int32(dst)],True,255,3, cv2.LINE_AA)

        else:
            print ("Not enough matches are found - %d/%d"  (len(good),MIN_MATCH_COUNT))
            matchesMask = None
            
        draw_params = dict(matchColor = (0,255,0), # draw matches in green color
                   singlePointColor = None,
                   matchesMask = matchesMask, # draw only inliers
                   flags = 2)

        img3 = cv2.drawMatches(img1,kp1,img2,kp2,good,None,**draw_params)
        
        cv2.imshow('img3', img3)
        cv2.imwrite('result_homography.jpg', img3)
        
def Stitching ():
        stitcher = cv2.createStitcher(True)
        img = cv2.cvtColor(a, cv2.COLOR_BGR2GRAY)
        filename2 = filedialog.askopenfilename()
        img2 = cv2.imread(filename2)
        img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2GRAY)
        result = stitcher.stitch((img,img2))
        
        cv2.imwrite("result_stitch.jpg", result[1])
        original = "original.tif"
cropped = "cropped.jpeg"

def Featurematcher():
        filename = filedialog.askopenfilename()
        img1 = cv2.imread(filename)
        filename = filedialog.askopenfilename()
        img2 = cv2.imread(filename)
        sift = cv2.SIFT_create()
        kp1, des1, = sift.detectAndCompute(img1,None)
        kp2, des2, = sift.detectAndCompute(img,None)
        bf = cv2.BFMatcher()
        matches = bf.knnMatch(des1,des2, k=2)
        good = []
        for m,n in matches:
            if m.distance < .1*n.distance:
                good.append([m])
        result = cv2.drawMatchesKnn(img1,kp1,img2,kp2,good)
        cv2.imshow('results',result)
    
def FaceDetection():
        face_cascade = cv2.CascadeClassifier('opencv-master/data/haarcascades/haarcascade_frontalface_default.xml')
        eye_cascade = cv2.CascadeClassifier('opencv-master/data/haarcascades/haarcascade_eye.xml')

        filename = filedialog.askopenfilename()
        img = cv2.imread(filename)
        img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(img_gray, 1.3, 5)
        for (x,y,w,h) in faces:
            img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
            roi_gray = img_gray[y:y+h, x:x+w]
            roi_color = img[y:y+h, x:x+w]
            eyes = eye_cascade.detectMultiScale(roi_gray)
            for (ex,ey,ew,eh) in eyes:
                cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)

        cv2.imshow('img',img)
        cv2.imwrite("FacesResults.jpg", img)
        
def contours():
    img = cv2.pyrDown(cv2.imread("Building.jpg", cv2.IMREAD_UNCHANGED))

    ret, thresh = cv2.threshold(cv2.cvtColor(img.copy(), cv2.COLOR_BGR2GRAY) , 127, 255, cv2.THRESH_BINARY)
    image, contours, hier = cv2.findContours(thresh, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    for c in contours:
# find bounding box coordinates
      x,y,w,h = cv2.boundingRect(c)
    cv2.rectangle(img, (x,y), (x+w, y+h), (0, 255, 0), 2)

# find minimum area
    rect = cv2.minAreaRect(c)
# calculate coordinates of the minimum area rectangle
    box = cv2.boxPoints(rect)
# normalize coordinates to integers
    box = np.int0(box)
# draw contours
    cv2.drawContours(img, [box], 0, (0,0, 255), 3)
# calculate center and radius of minimum enclosing circle
    (x,y),radius = cv2.minEnclosingCircle(c)
# cast to integers
    center = (int(x),int(y))
    radius = int(radius)
# draw the circle
    img = cv2.circle(img,center,radius,(0,255,0),2)

    cv2.drawContours(img, contours, -1, (255, 0, 0), 1)
    cv2.imshow("contours", img)
    cv2.imwrite("Saved Photos/ContourResults.jpg", img)

# %% [markdown]
# ### Desging the GUI here

# %%
#Creating my GUI
root = Tk()
root.title('Computer Vision OpenCV ToolBox')
root.geometry('900x900')

menu= Menu(root)
root.config(menu=menu)


subMenu = Menu(menu)
menu.add_cascade(label="Input", menu=subMenu)
subMenu.add_command(label="Load Image",command =LoadingImage)
subMenu.add_command(label="Load Video",command =LoadingImage)

subMenu1 = Menu(menu)
menu.add_cascade(label="Edge Detectors", menu=subMenu1)
subMenu1.add_command(label="Sobel",command =Sobel)
subMenu1.add_command(label="Laplacian",command =Laplacian)
subMenu1.add_command(label="Canny",command =Canny)

subMenu2 = Menu(menu)
menu.add_cascade(label="MorphologicalOps", menu=subMenu2)
subMenu2.add_command(label="Dilate",command =Dilation)
subMenu2.add_command(label="Erode",command =Erosion)
subMenu2.add_command(label="Open",command =Open)
subMenu2.add_command(label="Close",command =Close)

subMenu3 = Menu(menu)
menu.add_cascade(label="Noise", menu=subMenu3)
subMenu3.add_command(label="Salt&Pepper",command =SaltPepper)
subMenu3.add_command(label="Gaussian",command =Gaussian)
subMenu3.add_command(label="Poisson",command =Poisson)
subMenu3.add_command(label="Speckle",command =Speckle)

subMenu4 = Menu(menu)
menu.add_cascade(label="Filters", menu=subMenu4)
subMenu4.add_command(label="Average Filter",command =Averagingfilter)
subMenu4.add_command(label="Gaussian Filter",command =GaussianBlur)
subMenu4.add_command(label="Median Filter",command =Medianfilter)
subMenu4.add_command(label="Bilateral Filter",command =Bilateralfilter)


subMenu5 = Menu(menu)
menu.add_cascade(label="Compute Histogram", menu=subMenu5)
subMenu5.add_command(label="Histogram",command = Histogram)
subMenu5.add_command(label="Histogram Equilization",command =Equalization)

subMenu6 = Menu(menu)
menu.add_cascade(label="ROI", menu=subMenu6)
subMenu6.add_command(label="Region Of Interest",command = RegionOFInterest)

subMenu7 = Menu(menu)
menu.add_cascade(label="Other Options", menu=subMenu7)
subMenu7.add_command(label="ColorSpaces",command =ColorSpaces)
subMenu7.add_command(label="Extract Circle",command = HoughTransformCir)
subMenu7.add_command(label="Extract Lines",command = HoughTransformLin)

subMenu8 = Menu(menu)
menu.add_cascade(label="Shape Descriptors", menu=subMenu8)
subMenu8.add_command(label="Contours",command =contours)
subMenu8.add_command(label="Bounding Box",command =BoundingBox)
subMenu8.add_command(label="Minimum Enclosing Circle",command =Circle )

subMenu9 = Menu(menu)
menu.add_cascade(label="Corners Detectors", menu=subMenu9)
subMenu9.add_command(label="Harris",command =Harris)

subMenu10 = Menu(menu)
menu.add_cascade(label="Feature Detection", menu=subMenu10)
subMenu10.add_command(label="SIFT",command =SIFT2)
subMenu10.add_command(label="FAST",command =FAST)
subMenu10.add_command(label="Featutre Matching",command =Featurematcher)

subMenu11 = Menu(menu)
menu.add_cascade(label="Camera Calibration", menu=subMenu11)
subMenu11.add_command(label="Calibration",command =Calibration)
subMenu11.add_command(label="Epipolar",command =Epipolar)

subMenu12 = Menu(menu)
menu.add_cascade(label="Homography", menu=subMenu12)
subMenu12.add_command(label="Homography",command =Homography)
subMenu12.add_command(label="Stitching",command =Stitching)

subMenu13 = Menu(menu)
menu.add_cascade(label="Face Detection", menu=subMenu13)
subMenu13.add_command(label="Detect",command =FaceDetection)


root.mainloop()
# Out:
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "E:\Program Files\Anaconda\lib\tkinter\__init__.py", line 1699, in __call__
#     return self.func(*args)
#   File "<ipython-input-2-6752897537d6>", line 128, in Canny
#     cv2.imwrite("Saved Photos/CannyResults.png", Canny)
# TypeError: img is not a numpy array, neither a scalar
# Exception in Tkinter callback
# Traceback (most recent call last):
#   File "E:\Program Files\Anaconda\lib\tkinter\__init__.py", line 1699, in __call__
#     return self.func(*args)
#   File "<ipython-input-2-6752897537d6>", line 61, in HoughTransformLin
#     cv2.imwrite("Saved Photos/resulthoughLine.jpg", cimg)
# NameError: name 'cimg' is not defined
